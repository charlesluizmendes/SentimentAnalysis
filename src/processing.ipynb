# %%
import os
from dotenv import load_dotenv

# Load environment variables
load_dotenv()

# Access dataset variables
dataset_train_path = os.getenv("DATASET_TRAIN_PATH")
dataset_test_path = os.getenv("DATASET_TEST_PATH")
dataset_unsupervised_path = os.getenv("DATASET_UNSUPERVISED_PATH")

# Access training variables
training_result = os.getenv("TRAINING_RESULT")
training_model = os.getenv("TRAINING_MODEL")

# %%
from datasets import load_dataset

# Carrega os arquivos JSON locais
dataset = load_dataset('json', data_files={
    'train': dataset_train_path,
    'test': dataset_test_path,
    'unsupervised': dataset_unsupervised_path
})
# Out:
# Generating train split: 25000 examples [00:00, 322784.77 examples/s]
# Generating test split: 25000 examples [00:00, 377847.52 examples/s]
# Generating unsupervised split: 50000 examples [00:00, 405742.28 examples/s]

# %%
from transformers import BertTokenizer

# Load the tokenizer for a pretrained BERT model
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# %%
# Tokenizing function
def preprocess_function(examples):
    return tokenizer(
        examples['text'],
        add_special_tokens=True,
        truncation=True,
        padding='max_length',
        max_length=64,
        return_attention_mask=True
    )

# Apply tokenization to the dataset
tokenized_dataset = dataset.map(preprocess_function, batched=True)
# Out:
# Map: 100%|██████████| 25000/25000 [01:04<00:00, 387.44 examples/s]
# Map: 100%|██████████| 25000/25000 [01:04<00:00, 390.49 examples/s]
# Map: 100%|██████████| 50000/50000 [02:12<00:00, 377.34 examples/s]

# %%
from transformers import BertForSequenceClassification

# Load model
model = BertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=2)
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
from transformers import TrainingArguments

# Set up training arguments
training_args = TrainingArguments(
    output_dir=training_result,
    learning_rate=2e-5,
    per_device_train_batch_size=32,
    per_device_eval_batch_size=32,
    num_train_epochs=10,
    weight_decay=0.01,
    fp16=True,
)

# %%
# Split dataset into train and test sets
train_dataset = tokenized_dataset["train"]
test_dataset = tokenized_dataset["test"]

# %%
from evaluate import load

# Evaluation metrics 
accuracy = load("accuracy")
f1 = load("f1")
precision = load("precision")
recall = load("recall")

# %%
# Compute metric method
def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = logits.argmax(axis=-1)
    return {
        'accuracy': accuracy.compute(predictions=predictions, references=labels)['accuracy'],
        'f1': f1.compute(predictions=predictions, references=labels)['f1'],
        'precision': precision.compute(predictions=predictions, references=labels)['precision'],
        'recall': recall.compute(predictions=predictions, references=labels)['recall'],
    }

# %%
from transformers import Trainer

# Initialize the Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=test_dataset,
    processing_class=tokenizer,
    compute_metrics=compute_metrics
)

# %%
# Train the model
trainer.train()
# Out:
# d:\Visual Code\SentimentAnalysis\venv\Lib\site-packages\torch\nn\modules\module.py:1747: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
#     <div>
#
#       <progress value='7820' max='7820' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [7820/7820 15:54, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.451300</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.338500</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.277700</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.175700</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.136300</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.089500</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.057800</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.052000</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.033400</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.021400</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>0.020000</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.014700</td>
#     </tr>
#     <tr>
#       <td>6500</td>
#       <td>0.011000</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>0.008000</td>
#     </tr>
#     <tr>
#       <td>7500</td>
#       <td>0.006600</td>
#     </tr>
#   </tbody>
# </table><p>
# d:\Visual Code\SentimentAnalysis\venv\Lib\site-packages\torch\nn\modules\module.py:1747: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# d:\Visual Code\SentimentAnalysis\venv\Lib\site-packages\torch\nn\modules\module.py:1747: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# d:\Visual Code\SentimentAnalysis\venv\Lib\site-packages\torch\nn\modules\module.py:1747: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# d:\Visual Code\SentimentAnalysis\venv\Lib\site-packages\torch\nn\modules\module.py:1747: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# d:\Visual Code\SentimentAnalysis\venv\Lib\site-packages\torch\nn\modules\module.py:1747: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# d:\Visual Code\SentimentAnalysis\venv\Lib\site-packages\torch\nn\modules\module.py:1747: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# d:\Visual Code\SentimentAnalysis\venv\Lib\site-packages\torch\nn\modules\module.py:1747: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# d:\Visual Code\SentimentAnalysis\venv\Lib\site-packages\torch\nn\modules\module.py:1747: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# d:\Visual Code\SentimentAnalysis\venv\Lib\site-packages\torch\nn\modules\module.py:1747: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# d:\Visual Code\SentimentAnalysis\venv\Lib\site-packages\torch\nn\modules\module.py:1747: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# d:\Visual Code\SentimentAnalysis\venv\Lib\site-packages\torch\nn\modules\module.py:1747: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# d:\Visual Code\SentimentAnalysis\venv\Lib\site-packages\torch\nn\modules\module.py:1747: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# d:\Visual Code\SentimentAnalysis\venv\Lib\site-packages\torch\nn\modules\module.py:1747: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# d:\Visual Code\SentimentAnalysis\venv\Lib\site-packages\torch\nn\modules\module.py:1747: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# d:\Visual Code\SentimentAnalysis\venv\Lib\site-packages\torch\nn\modules\module.py:1747: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# TrainOutput(global_step=7820, training_loss=0.1084926261926246, metrics={'train_runtime': 955.0353, 'train_samples_per_second': 261.77, 'train_steps_per_second': 8.188, 'total_flos': 8222220480000000.0, 'train_loss': 0.1084926261926246, 'epoch': 10.0})

# %%
# Evaluate the model
results = trainer.evaluate()
print(results)
# Out:
# d:\Visual Code\SentimentAnalysis\venv\Lib\site-packages\torch\nn\modules\module.py:1747: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
#     <div>
#
#       <progress value='782' max='782' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [782/782 00:24]
#     </div>
# {'eval_loss': 1.217032790184021, 'eval_accuracy': 0.83852, 'eval_f1': 0.8400744760923821, 'eval_precision': 0.832064662952209, 'eval_recall': 0.84824, 'eval_runtime': 24.5586, 'eval_samples_per_second': 1017.974, 'eval_steps_per_second': 31.842, 'epoch': 10.0}

# %%
import os

# Create directory model
os.makedirs(training_model, exist_ok=True)

# %%
# Save model
trainer.save_model(training_model)

# Save tokenizer
tokenizer.save_pretrained(training_model)
# Out:
# ('../model\\tokenizer_config.json',
#  '../model\\special_tokens_map.json',
#  '../model\\vocab.txt',
#  '../model\\added_tokens.json')
